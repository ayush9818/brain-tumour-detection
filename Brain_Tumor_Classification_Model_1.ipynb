# %% [markdown]
# <a href="https://colab.research.google.com/github/ayush9818/brain-tumour-detection/blob/main/Brain_Tumor_Classification_Model_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import cv2
import os
import numpy as np
from tqdm import tqdm
import time
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Input, ZeroPadding2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle

# %%
df = pd.read_csv('/content/drive/MyDrive/brain_tumor_dataset/df.csv')
train_df = df[df['type']=='train']
print(train_df.shape)

valid_df = df[df['type']=='valid']
print(valid_df.shape)
# Out:
# (1494, 5)
# (262, 5)

# %%
valid_df['label'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
IMG_HEIGHT, IMG_WIDTH  = (240,240)

# %%
def load_data(df, img_height, img_width):
  X = []
  y = []
  for idx,sample in df.iterrows():
    image_path = sample['image_path']
    image = cv2.imread(image_path)
    image = cv2.resize(image, (img_height, img_width))
    image = np.array(image).astype('float32') / 255.
    X.append(image)
    if sample['label'] == "yes":
      y.append(1)
    else:
      y.append(0)
  return np.array(X), np.array(y)

# %%
X_train, y_train = load_data(train_df, IMG_HEIGHT, IMG_WIDTH)

# %%
print("Shape of X_train : {}".format(X_train.shape))
print("Shape of y_train : {}".format(y_train.shape))
# Out:
# Shape of X_train : (1494, 240, 240, 3)
# Shape of y_train : (1494,)

# %%
import matplotlib.pyplot as plt
plt.imshow(X_train[0])

# %%
X_val, y_val = load_data(valid_df, IMG_HEIGHT, IMG_WIDTH)

# %%
print("Shape of X_val : {}".format(X_val.shape))
print("Shape of y_val : {}".format(y_val.shape))
# Out:
# Shape of X_val : (262, 240, 240, 3)
# Shape of y_val : (262,)

# %%
plt.imshow(X_val[0])

# %%
def build_model(input_shape):
  X_input = Input(input_shape)
  X = ZeroPadding2D((2, 2))(X_input)
  X = Conv2D(32, (7, 7), strides = (1, 1), name = 'conv0')(X)
  X = BatchNormalization(axis = 3, name = 'bn0')(X)
  X = Activation('relu')(X)
  X = MaxPooling2D((4, 4), name='max_pool0')(X)
  X = MaxPooling2D((4, 4), name='max_pool1')(X)
  X = Flatten()(X)
  X = Dense(1, activation='sigmoid', name='fc')(X)
  
  model = Model(inputs = X_input, outputs = X)
  
  return model

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
model = build_model(IMG_SHAPE)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 240, 240, 3)]     0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 244, 244, 3)       0
# _________________________________________________________________
# conv0 (Conv2D)               (None, 238, 238, 32)      4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 238, 238, 32)      128
# _________________________________________________________________
# activation (Activation)      (None, 238, 238, 32)      0
# _________________________________________________________________
# max_pool0 (MaxPooling2D)     (None, 59, 59, 32)        0
# _________________________________________________________________
# max_pool1 (MaxPooling2D)     (None, 14, 14, 32)        0
# ...

# %%
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return f"{h}:{m}:{round(s,1)}"

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
filepath="/content/drive/MyDrive/brain_tumor_dataset/models/cnn-parameters-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=20, validation_data=(X_val, y_val), callbacks=[checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/20
# 47/47 [==============================] - 115s 2s/step - loss: 0.3576 - accuracy: 0.8394 - val_loss: 0.5695 - val_accuracy: 0.6718
#
# Epoch 00001: val_accuracy improved from -inf to 0.67176, saving model to /content/drive/MyDrive/brain_tumor_dataset/models/cnn-parameters-improvement-01-0.67.hdf5
# Epoch 2/20
# 47/47 [==============================] - 115s 2s/step - loss: 0.3449 - accuracy: 0.8414 - val_loss: 0.6396 - val_accuracy: 0.6489
#
# Epoch 00002: val_accuracy did not improve from 0.67176
# Epoch 3/20
# 47/47 [==============================] - 115s 2s/step - loss: 0.3655 - accuracy: 0.8400 - val_loss: 0.4901 - val_accuracy: 0.7710
#
# Epoch 00003: val_accuracy improved from 0.67176 to 0.77099, saving model to /content/drive/MyDrive/brain_tumor_dataset/models/cnn-parameters-improvement-03-0.77.hdf5
# Epoch 4/20
# 47/47 [==============================] - 115s 2s/step - loss: 0.3255 - accuracy: 0.8608 - val_loss: 0.5134 - val_accuracy: 0.7939
#
# ...

# %%
history = model.history.history
for key in history.keys():
  print(key)
# Out:
# loss
# accuracy
# val_loss
# val_accuracy

# %%
def plot_metrics(history):
    
    train_loss = history['loss']
    val_loss = history['val_loss']
    train_acc = history['accuracy']
    val_acc = history['val_accuracy']
    
    # Loss
    plt.figure()
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    plt.show()
    
    # Accuracy
    plt.figure()
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    plt.show()

# %%
plot_metrics(history)

# %%
test_df = df[df['type']=='test']
test_df.head()
# Out:
#      Unnamed: 0                                         image_path  ...  type label
# 785         785  /content/drive/MyDrive/brain_tumor_dataset/aug...  ...  test   yes
# 786         786  /content/drive/MyDrive/brain_tumor_dataset/aug...  ...  test   yes
# 787         787  /content/drive/MyDrive/brain_tumor_dataset/aug...  ...  test   yes
# 788         788  /content/drive/MyDrive/brain_tumor_dataset/aug...  ...  test   yes
# 789         789  /content/drive/MyDrive/brain_tumor_dataset/aug...  ...  test   yes
#
# [5 rows x 5 columns]

# %%
X_test, y_test = load_data(test_df, IMG_HEIGHT, IMG_WIDTH)
print(X_test.shape)
print(y_test.shape)
# Out:
# (308, 240, 240, 3)
# (308,)

# %%
final_model = load_model('/content/drive/MyDrive/brain_tumor_dataset/models/cnn-parameters-improvement-04-0.79.hdf5')
print("model loaded")
# Out:
# model loaded

# %%
loss, accuracy = final_model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 6s 584ms/step - loss: 0.5284 - accuracy: 0.7760

# %%
y_pred = final_model.predict(X_test)

for i in range(y_pred.shape[0]):
  if y_pred[i]>=0.5:
    y_pred[i]=1
  else:
    y_pred[i]=0

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[121,  25],
#        [ 44, 118]])

# %%
import seaborn as sn
df_cm = pd.DataFrame(cm, index = ['no', 'yes'],
                  columns = ["no","yes"])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, fmt='g')
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.83      0.78       146
#            1       0.83      0.73      0.77       162
#
#     accuracy                           0.78       308
#    macro avg       0.78      0.78      0.78       308
# weighted avg       0.78      0.78      0.78       308
